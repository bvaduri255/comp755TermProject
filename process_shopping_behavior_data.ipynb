# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("shopping_behavior_updated.csv")
print(df.shape)

drop_cols = ["Customer ID"]
df = df.drop(columns=drop_cols)
df.head(-20)
# Out:
# (3900, 18)
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3875   63  Female            Hat  Accessories                     51
# 3876   60  Female          Shoes     Footwear                     85
# 3877   28  Female         Hoodie     Clothing                     96
# 3878   60  Female            Hat  Accessories                     42
# 3879   26  Female          Skirt     Clothing                     63
#
#             Location Size      Color  Season  Review Rating  \
# 0           Kentucky    L       Gray  Winter            3.1
# ...

# %%
for col in ['Gender', 'Item Purchased', 'Category', 'Location', 'Size', 'Color', 'Season', 'Subscription Status', 'Shipping Type', 'Discount Applied', 'Promo Code Used', 'Payment Method', 'Frequency of Purchases']:
    codes, unique = pd.factorize(df[col])
    df[col] = codes

# payment_method = df.pop("Gender")
# df["Gender"] = payment_method
df.head()
# Out:
#    Age  Gender  Item Purchased  Category  Purchase Amount (USD)  Location  \
# 0   55       0               0         0                     53         0
# 1   19       0               1         0                     64         1
# 2   50       0               2         0                     73         2
# 3   21       0               3         1                     90         3
# 4   45       0               0         0                     49         4
#
#    Size  Color  Season  Review Rating  Subscription Status  Shipping Type  \
# 0     0      0       0            3.1                    0              0
# 1     0      1       0            3.1                    0              0
# 2     1      1       1            3.1                    0              1
# 3     2      1       1            3.5                    0              2
# 4     2      2       1            2.7                    0              1
#
#    Discount Applied  Promo Code Used  Previous Purchases  Payment Method  \
# ...

# %%
df.to_csv("shopping_processed.csv", header=False, index=False)
